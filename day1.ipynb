# %% [markdown]
# <a href="https://colab.research.google.com/github/halgekishan/linear-Regression/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# day 4

# %%
import pandas as pd
import numpy as np

# %%
arr=np.array([1,2,3,4,5,6,7])
print(arr)
print(arr.sum())
# Out:
# [1 2 3 4 5 6 7]
# 28

# %%
df=pd.read_csv('/content/student_performance.csv')
print(df)
# Out:
#     student_id  gender  age  study_hours_per_week  attendance_rate  \
# 0      STU0001    Male   15                    25             63.8
# 1      STU0002  Female   15                     2             54.7
# 2      STU0003  Female   19                    10             90.5
# 3      STU0004    Male   16                    26             66.8
# 4      STU0005  Female   15                    25             73.0
# ..         ...     ...  ...                   ...              ...
# 495    STU0496  Female   19                     6             78.3
# 496    STU0497  Female   16                    27             61.1
# 497    STU0498  Female   18                    16             72.3
# 498    STU0499    Male   17                    29             91.3
# 499    STU0500    Male   15                    29             75.4
#
#     parent_education internet_access extracurricular  previous_score  \
# 0           Bachelor             Yes             Yes              41
# ...

# %%
print(df.head())
# Out:
#   student_id  gender  age  study_hours_per_week  attendance_rate  \
# 0    STU0001    Male   15                    25             63.8
# 1    STU0002  Female   15                     2             54.7
# 2    STU0003  Female   19                    10             90.5
# 3    STU0004    Male   16                    26             66.8
# 4    STU0005  Female   15                    25             73.0
#
#   parent_education internet_access extracurricular  previous_score  \
# 0         Bachelor             Yes             Yes              41
# 1         Bachelor             Yes             Yes              83
# 2      High School             Yes              No              73
# 3      High School              No             Yes              75
# 4      High School              No             Yes              67
#
#    final_score passed
# 0           67    Yes
# 1           28     No
# 2           49     No
# 3           70    Yes
# 4           77    Yes

# %%
print(df.shape)
# Out:
# (500, 11)

# %%
print(df.columns)
# Out:
# Index(['student_id', 'gender', 'age', 'study_hours_per_week',
#        'attendance_rate', 'parent_education', 'internet_access',
#        'extracurricular', 'previous_score', 'final_score', 'passed'],
#       dtype='object')

# %%
mode_parent_education = df['parent_education'].mode()[0]

df['parent_education'].fillna(mode_parent_education, inplace=True)

print(f"Null values in 'parent_education' after filling: {df['parent_education'].isnull().sum()}")
print("First 5 rows of 'parent_education' after imputation:")
print(df['parent_education'].head())
# Out:
# Null values in 'parent_education' after filling: 0
# First 5 rows of 'parent_education' after imputation:
# 0       Bachelor
# 1       Bachelor
# 2    High School
# 3    High School
# 4    High School
# Name: parent_education, dtype: object

# %%
print(df.describe())
# Out:
#               age  study_hours_per_week  attendance_rate  previous_score  \
# count  500.000000            500.000000       500.000000      500.000000
# mean    16.978000             15.312000        76.380600       62.986000
# std      1.434445              8.568167        13.817681       18.937451
# min     15.000000              2.000000        50.200000       30.000000
# 25%     16.000000              8.000000        64.475000       46.000000
# 50%     17.000000             15.000000        76.500000       64.000000
# 75%     18.000000             23.000000        88.525000       79.000000
# max     19.000000             30.000000       100.000000       95.000000
#
#        final_score
# count   500.000000
# mean     55.980000
# std      15.373754
# min      20.000000
# 25%      45.000000
# 50%      56.000000
# 75%      68.000000
# max      95.000000

# %%
print(df.age)
# Out:
# 0      15
# 1      15
# 2      19
# 3      16
# 4      15
#        ..
# 495    19
# 496    16
# 497    18
# 498    17
# 499    15
# Name: age, Length: 500, dtype: int64

# %%
print(df['age'].isnull())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: age, Length: 500, dtype: bool

# %%
print(np.sum(df['age']))
# Out:
# 8489

# %%
print(np.mean(df['age']))
# Out:
# 16.978

# %%
print(np.min(df['age']))
# Out:
# 15

# %%
print('Summary of null values per column:')
print(df.isnull().sum())
# Out:
# Summary of null values per column:
# student_id                0
# gender                    0
# age                       0
# study_hours_per_week      0
# attendance_rate           0
# parent_education        117
# internet_access           0
# extracurricular           0
# previous_score            0
# final_score               0
# passed                    0
# dtype: int64

# %%
print(np.max(df['age']))
# Out:
# 19
